# %% [markdown]
# <a href="https://colab.research.google.com/github/AmitKunduA/Class_2_Assignment/blob/main/Python2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Python 2**

# %% [markdown]
# ## **Function**

# %%
print("Again Welcome to Skill Morph") #Print Function
# Out:
# Again Welcome to Skill Morph

# %%
def greet( ):
  print('kundu')
greet( )
print('amit')
# Out:
# kundu
# amit

# %%
def greet(name):
  print('Hallo',name)
greet('Amit')
# Out:
# Hallo Amit

# %%
def add_number(num1,num2):
  sum=num1+num2
  print('sum:',sum)
add_number(57,43)
# Out:
# sum: 100

# %%
def greet(name,message='Hello'):
    print(message,name)
greet('Amit','Good Evening')
greet('Kundu')
# Out:
# Good Evening Amit
# Hello Kundu

# %%
def add_all(*numbers):
  return sum(numbers)

print(add_all(52,57,43))
# Out:
# 152

# %%
message='Hello'

def greet():
    print('Local',message)

greet()

print('Global',message)
# Out:
# Local Hello
# Global Hello

# %%
c=2

def add():
  global c
  c=c+50
  print(c)
add(f )
# Out:
# 52

# %%
import math # Importing the math module

num = 45.67

print(math.sqrt(num))
# Out:
# 6.757958271549182

# %%
def x(): ## Funstion Examples
  return 100

def sum(num1, num2):
  s = num1 + num2
  return s

def sub(num1, num2):
  s = num1 - num2
  return s

print(x())
# Out:
# 100

# %%
#H1 Write a function to calculate the sum of numbers from 1 to N.

# %%
def sum(n):
 sum=0
 for i in range(1,n+1):
   sum += i
 return sum

n=52
print(f'The sum of numbers from 1 to {n} is:',sum(n))
# Out:
# The sum of numbers from 1 to 52 is: 1378

# %%
#H2 Write a function that returns the square of a number.

# %%
def square(number):
    return(number ** 2)

number=57
print('Square is',square(number))
# Out:
# Square is 3249

# %%
#H3 Write a function that checks whether a number is even/odd.

# %%
def check(n):
    if n % 2 == 0:
      return 'even'
    else:
      return 'Odd'
n=57
print('The number is:',check(n))
# Out:
# The number is: Odd

# %%
#H4 Write a function that returns the larger number from two given numbers.

# %%
def large(a,b):
  if a>b :
    return a
  elif a<b:
    return b
  else:
    return 0

num1,num2=57,52
print("the largest number is :",large(num1,num2))
# Out:
# the largest number is : 57

# %% [markdown]
# ## **Lists**

# %%
li = [10, 20, 20, 5, 40, 50] ## List Examples

print(li)

print(type(li))
# Out:
# [10, 20, 20, 5, 40, 50]
# <class 'list'>

# %%
li = [5, 10, 15, 30, 50]

sum = 0

for x in range(5):
  #print(x, "=>", li[x])
  sum = sum + li[x] ## 0 + 5 = 5 + 10 = 15....

print(sum)
# Out:
# 110

# %%
# a list containing strings and numbers
student = ['Skill', 2026, 'Morph']
print(student)

# an empty list
empty_list = []
print(empty_list)
# Out:
# ['Skill', 2026, 'Morph']
# []

# %%
## Using list() to Create Lists

x = "SKILL MORPH"

# convert to list
result = list(x)
print(result)
# Out:
# ['S', 'K', 'I', 'L', 'L', ' ', 'M', 'O', 'R', 'P', 'H']

# %%
li = [90, 10, 100]

print(li[-1])
# Out:
# 100

# %%
## One example of list with condition

li = [3, 50, 20, 70, 30]

print(li)

for i in range(0, 5):
 ## print(i, "=>", li[i])
  if li[i] > 10:
    print(li[i])
# Out:
# [3, 50, 20, 70, 30]
# 50
# 20
# 70
# 30

# %%
#List with Loop

# %%
## Slicing of a List in Python

L = [5, 10, 30, 40, 20, 50]

print(L[2:5])
L.sort(reverse = True)
print(L)
# Out:
# [30, 40, 20]
# [50, 40, 30, 20, 10, 5]

# %%
#H5  	Write a Python program to create a list of 10 integers. Then perform the following operations:
  #Append an element to the list.
  #Insert an element at a specific position.
  #Remove an element from the list.
  #Pop an element from a specific position.

# %%
li=[6, 23, 27, 31, 43, 52, 57, 62, 70, 100]
print(li)
li.append(152)
print(li)
li.insert(7,60)
print(li)
del li[8]
print(li)
li.pop(8)
print(li)
# Out:
# [6, 23, 27, 31, 43, 52, 57, 62, 70, 100]
# [6, 23, 27, 31, 43, 52, 57, 62, 70, 100, 152]
# [6, 23, 27, 31, 43, 52, 57, 60, 62, 70, 100, 152]
# [6, 23, 27, 31, 43, 52, 57, 60, 70, 100, 152]
# [6, 23, 27, 31, 43, 52, 57, 60, 100, 152]

# %%
#H6 Write a program to find all unique elements in the list.

# %%
li=[1, 2, 3, 4, 5, 6, 52, 57, 6, 3]
uniqueli=list(set(li))
print(set(li))
print(uniqueli)
# Out:
# {1, 2, 3, 4, 5, 6, 52, 57}
# [1, 2, 3, 4, 5, 6, 52, 57]

# %%
#H7 Write a Python program to calculate the mean of a list of numbers.

# %%
lim=[27, 31, 43, 52, 57]
sum=0
for li in lim:
  sum += li

sum=sum/5

print(sum)
# Out:
# 42.0

# %%
#H8 Classify Numbers into Even and Odd Lists

# %%
numbers=[22, 23, 31, 43, 52, 57]
even=[]
odd=[]
for num in numbers:
  if num  %2 == 0:
    even.append(num)
  else:
    odd.append(num)

print('Even numbers:',even)
print('Odd numbers:',odd)
# Out:
# Even numbers: [22, 52]
# Odd numbers: [23, 31, 43, 57]

# %% [markdown]
# ## **Tuples**

# %%
t = (3, 10, 5, 6)

print(t)

print(len(t)) # Length of a tuple

t1 = (3, "SKill", "2026")
print(t1[1])

print(t1)
# Out:
# (3, 10, 5, 6)
# 4
# SKill
# (3, 'SKill', '2026')

# %%
## Tuple Function

my_tuple = (1, 2, 3, 1, 1, 4, 52, 57, 57)
print(my_tuple.count(57))  # Output: 3

print(my_tuple.index(52))

another_tuple  = (4, 5, 6, 7, 8)

new_tuple = my_tuple + another_tuple # Concatenate tuples
print(new_tuple)
# Out:
# 2
# 6
# (1, 2, 3, 1, 1, 4, 52, 57, 57, 4, 5, 6, 7, 8)

# %% [markdown]
# ## **String**

# %%
# Assigning values to variables
str1 = "Skill Morph!"
str2 = "I love Python."
str3 = "Skill Morph!"

# Compare str1 and str2
print(str1 == str2)  # This will print: False

# Compare str1 and str3
print(str1 == str3)  # This will print: True
# Out:
# False
# True

# %%
## Iteration

sm = 'Amit Kundu'

for char in sm:
  print(char)

for i in range(0, len(sm)):
  print(sm[i])
# Out:
# A
# m
# i
# t
#
# K
# u
# n
# d
# u
# A
# m
# i
# t
#
# K
# u
# n
# d
# u

# %%
## String Functions

# Initial string
s = "Skill Morph"

# 1. upper()
print(s.upper())  # Converts all characters to uppercase
# 2. lower()
print(s.lower())  # Converts all characters to lowercase
# 3. partition()
print(s.partition(' '))  # Splits the string at the first occurrence of ' '
# 4. replace()
print(s.replace('Morph', 'Master'))  # Replaces 'Morph' with 'Master'
# 5. find()
print(s.find('Morph'))  # Returns the index of 'Morph' in the string, or -1 if not found
# 6. rstrip()
print(s.rstrip())  # Removes trailing spaces from the string
# 7. split()
print(s.split())  # Splits the string into a list at spaces
# 8. startswith()
print(s.startswith('Skill'))  # Checks if the string starts with 'Skill'
# 9. isnumeric()
print(s.isnumeric())  # Checks if all characters in the string are numeric (returns False)
# 10. index()
print(s.index('Morph'))  # Returns the index of the first occurrence of 'Morph'
# Out:
# SKILL MORPH
# skill morph
# ('Skill', ' ', 'Morph')
# Skill Master
# 6
# Skill Morph
# ['Skill', 'Morph']
# True
# False
# 6

# %%
s ='Amit Kundu'

print(len(s)) # Lentgth Function
# Out:
# 10

# %%
st = "madam"
s2 = "abcd"

if st == s2:
  print("Palindrome")
else:
  print("Not Palindrome")
# Out:
# Not Palindrome

# %%
num1 = 100
num2 = 200

print(num1 + num2)

st1 = "Skill"
st2 = "Morph"

print(st1 + ' '+ st2)
# Out:
# 300
# Skill Morph

# %%
s='What\'s your name?'
a='\'Amit Kundu\''

print(s)
print(a)
# Out:
# What's your name?
# 'Amit Kundu'

# %% [markdown]
# ## **Sets**

# %%
s={1, 3, 5, 6, 7, 3, 10}
a={1, 3, 5, 7, 52, 57}

print(len(s))
print(len(a))
print('Union of s and a:',s.union(a))
print('Intersection of s and a:',s.intersection(a))
print('Difference between s and a:',s.difference(a))
print('Symmetric difference between s and a:',s.symmetric_difference(a))
# Out:
# 6
# 6
# Union of s and a: {1, 3, 5, 6, 7, 10, 52, 57}
# Intersection of s and a: {1, 3, 5, 7}
# Difference between s and a: {10, 6}
# Symmetric difference between s and a: {52, 6, 57, 10}

# %%
# Create a set of even numbers
even_numbers = {2, 4, 6, 8}

# Print the set
print('Set:', even_numbers)

# Find the number of elements in the set
print('Total Elements:', len(even_numbers))

b={43, 52, 57}
c={52, 57, 43}

if b == c:
  print('b and c are equal')
else:
  print('b and c are not equal')
# Out:
# Set: {8, 2, 4, 6}
# Total Elements: 4
# b and c are equal

# %% [markdown]
# ## **Dictionaries**

# %%
# key-value pairs

# %%
#H9: Write a program to find the key in a dictionary that has the maximum value. Input: {‘a’: 10, ‘b’: 20, ‘c’: 15} Output: ‘b’

# %%
results={'a':10,'b':20,'c':15 }

for result in results:
    print(results)
# Out:
# {'a': 10, 'b': 20, 'c': 15}
# {'a': 10, 'b': 20, 'c': 15}
# {'a': 10, 'b': 20, 'c': 15}

# %%
#10:

# %% [markdown]
# # **Thank You!**
